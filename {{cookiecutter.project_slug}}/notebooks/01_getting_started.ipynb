# %% [markdown]
# # Getting Started with {{ cookiecutter.project_name }}
#
# This notebook demonstrates the basic setup and workflow for experiments.

# %%
# Import standard libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Import project utilities
from {{ cookiecutter.package_name }}.utils import hello_experiment

# Configure visualization
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
# %matplotlib inline

# %% [markdown]
# ## Test Utilities

# %%
print(hello_experiment())

# %% [markdown]
# ## Load Data
#
# Load your datasets from the `data/` directory.

# %%
# Example: Load a CSV file
# df = pd.read_csv('../data/your_dataset.csv')
# df.head()

# %% [markdown]
# ## Explore & Analyze
#
# Add your analysis code here.

# %%
# Your code here

# %% [markdown]
# ## Save Results
#
# Save outputs to the `outputs/` directory.

# %%
# Example: Save a plot
# plt.figure(figsize=(10, 6))
# plt.plot([1, 2, 3], [1, 4, 9])
# plt.savefig('../outputs/example_plot.png')
# plt.show()
